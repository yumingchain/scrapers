# %%
import sys
sys.path.append("..")

from playwright.async_api import async_playwright, TimeoutError
import requests
from urllib.parse import urlparse, parse_qs

import pandas as pd
from models.cases import Case
from models.scraper import ScraperBase
from datetime import date, datetime, time
from tempfile import NamedTemporaryFile
from rich.console import Console
from models.leads import Lead
from models.scraper import ScraperBase
from rich.progress import Progress

import re
import os
from dotenv import load_dotenv
from twocaptcha import TwoCaptcha
load_dotenv(dotenv_path='.env')
TWOCAPTCHA_API_KEY = os.getenv('TWOCAPTCHA_API_KEY')

console = Console()

class WestViginiaScraper(ScraperBase):
    
    def to_datetime(self, date_str):
        if date_str is None:
            return None
        else:
            return datetime.strptime(date_str, '%m/%d/%Y')
    
    async def init_browser(self):
        console.log("Initation of Browser...")
        pw = await async_playwright().start()
        self.browser = await pw.chromium.launch(headless=False)
        self.context = await self.browser.new_context()
        self.page = await self.context.new_page()
        self.url = "https://eapps.courts.state.va.us/ocis/landing"
        await self.page.goto(self.url)

        await self.page.wait_for_timeout(2000)
        accept_button = await self.page.query_selector('#acceptTerms')
        if accept_button:
            await accept_button.click()
        else:
            print("The 'Accept' button was not found.")
        await self.page.wait_for_load_state("networkidle")
        await self.page.wait_for_timeout(2000)
        
    
    async def search_by_name(self, search_parameter):
        cookies = await self.context.cookies()
        self.req_cookies = {cookie['name']: cookie['value'] for cookie in cookies} # type:ignore

        console.log(f"self.req_cookies------------{self.req_cookies}")
        url = "https://eapps.courts.state.va.us/ocis-rest/api/public/search"
        data = {"courtLevels":[],"divisions":["Adult Criminal/Traffic"],"selectedCourts":[],"searchString":[f"{search_parameter}"],"searchBy":"N"}
        res = requests.post(url, json=data, cookies=self.req_cookies)
        res_dict = res.json()
        search_result = res_dict['context']['entity']['payload']['searchResults'] 
        return search_result

    def get_case_detail(self, search_result):
        url = "https://eapps.courts.state.va.us/ocis-rest/api/public/getCaseDetails"
        data = search_result
        res = requests.post(url, json=data, cookies=self.req_cookies)
                
        detail_data = res.json()
        case_id = detail_data["context"]["entity"]["payload"]["caseTrackingID"]

        charges = []
        charge = {}
        case_charge = detail_data["context"]["entity"]["payload"]["caseCharge"]

        filing_date = case_charge["chargeFilingDate"]
        offense_date = case_charge["offenseDate"]
        arrest_date = case_charge.get("arrestDate")
        charge["offense_date"] =self.to_datetime(offense_date) #type: ignore
        charge["filing_date"] = self.to_datetime(filing_date) #type: ignore
        charge["arrest_date"] = self.to_datetime(arrest_date) #type: ignore
        charges.append(charge)
        
        
        caseCourt = detail_data["context"]["entity"]["payload"]["caseCourt"]
        court_id = caseCourt["fipsCode"]+caseCourt["courtCategoryCode"]["value"]
        
        caseParticipant = detail_data["context"]["entity"]["payload"]["caseParticipant"]
        for participant in caseParticipant:
            if participant["participantCode"] == "DEF":
                contact_info = participant["contactInformation"]
                last_name = contact_info["personName"].get("personSurName")
                first_name = contact_info["personName"].get("personGivenName")
                middle_name = contact_info["personName"].get("personMiddleName")
                address_city  = contact_info["primaryAddress"].get("locationCityName")
                address_zip = contact_info["primaryAddress"].get("locationState")
                address_state_code = contact_info["primaryAddress"].get("locationPostalCode")
                gender = participant["personalDetails"]["gender"]
                birth_date = participant["personalDetails"].get("maskedBirthDate")
        case_dict = {
                "case_id": case_id,
                "court_id": court_id,
                "charges": charges,
                "filing_date": filing_date,
                "arrest_date": arrest_date,
                "offense_date": offense_date,
                "first_name": first_name,
                "middle_name": middle_name,
                "last_name": last_name,
                "gender": gender,
                "birth_date": birth_date,
                "address_city": address_city,
                "address_zip": address_zip,
                "address_state_code": address_state_code
            }
        return case_dict

    async def scrape(self, search_parameter):
        search_name = search_parameter['name']
        await self.init_browser()
        search_results = await self.search_by_name(search_name)        
        case_dicts = []
        for result in search_results:
            case_dict = self.get_case_detail(result)
            case_dicts.append(case_dict)

            case = Case(**case_dict)
            lead = Lead(**case_dict)
            self.insert_case(case)
            self.insert_lead(lead)
        print(case_dicts)

        await self.browser.close()

# %%
wvscraper = WestViginiaScraper()
await wvscraper.scrape({'name':'AB'})
# Out:
# [21:29:53] Initation of Browser...                                                                 ]8;id=883058;file:///tmp/ipykernel_2656/2230992997.py\2230992997.py]8;;\:]8;id=793377;file:///tmp/ipykernel_2656/2230992997.py#36\36]8;;\
# [21:30:00] self.req_cookies------------{'OES_TC_JSESSIONID':                                       ]8;id=406210;file:///tmp/ipykernel_2656/2230992997.py\2230992997.py]8;;\:]8;id=851159;file:///tmp/ipykernel_2656/2230992997.py#58\58]8;;\
#            '9A0435A280939F3CA44478CE2B1281FC.appServer3'}
# {'case_id': '0035370100', 'court_id': '595J', 'charges': [{'offense_date': datetime.datetime(2010, 1, 18, 0, 0), 'filing_date': datetime.datetime(2010, 1, 20, 0, 0), 'arrest_date': datetime.datetime(2010, 1, 19, 0, 0)}], 'filing_date': '01/20/2010', 'arrest_date': '01/19/2010', 'offense_date': '01/18/2010', 'first_name': 'ANTHONY', 'middle_name': 'CORNELIUS', 'last_name': 'BROWN', 'gender': 'M', 'birth_date': '07/25', 'address_city': 'EMPORIA', 'address_zip': 'VA', 'address_state_code': '23847'}
# {'case_id': '2000426300', 'court_id': '019G', 'charges': [{'offense_date': datetime.datetime(2020, 9, 3, 0, 0), 'filing_date': datetime.datetime(2020, 9, 3, 0, 0), 'arrest_date': None}], 'filing_date': '09/03/2020', 'arrest_date': None, 'offense_date': '09/03/2020', 'first_name': None, 'middle_name': None, 'last_name': 'OWNER UNKNOWN', 'gender': 'O', 'birth_date': None, 'address_city': None, 'address_zip': None, 'address_state_code': None}
# {'case_id': '1821989000', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2017, 10, 22, 0, 0), 'filing_date': datetime.datetime(2018, 10, 24, 0, 0), 'arrest_date': None}], 'filing_date': '10/24/2018', 'arrest_date': None, 'offense_date': '10/22/2017', 'first_name': 'ABDULLAH', 'middle_name': 'B', 'last_name': 'A A ALMUTAIRI', 'gender': 'O', 'birth_date': None, 'address_city': 'TOWSON', 'address_zip': 'MD', 'address_state_code': '21286'}
# {'case_id': '1821985600', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2017, 9, 23, 0, 0), 'filing_date': datetime.datetime(2018, 10, 24, 0, 0), 'arrest_date': None}], 'filing_date': '10/24/2018', 'arrest_date': None, 'offense_date': '09/23/2017', 'first_name': 'ABDULLAH', 'middle_name': 'B', 'last_name': 'A A ALMUTAIRI', 'gender': 'O', 'birth_date': None, 'address_city': 'TOWSON', 'address_zip': 'MD', 'address_state_code': '21286'}
# {'case_id': '1916317200', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 6, 23, 0, 0), 'filing_date': datetime.datetime(2019, 8, 8, 0, 0), 'arrest_date': None}], 'filing_date': '08/08/2019', 'arrest_date': None, 'offense_date': '06/23/2018', 'first_name': 'ABDULMOHSEN', 'middle_name': 'ALI', 'last_name': 'A ALAMRI', 'gender': 'O', 'birth_date': None, 'address_city': 'ELKTON', 'address_zip': 'MD', 'address_state_code': '21921'}
# {'case_id': '1916317300', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 6, 23, 0, 0), 'filing_date': datetime.datetime(2019, 8, 8, 0, 0), 'arrest_date': None}], 'filing_date': '08/08/2019', 'arrest_date': None, 'offense_date': '06/23/2018', 'first_name': 'ABDULMOHSEN', 'middle_name': 'ALI', 'last_name': 'A ALAMRI', 'gender': 'O', 'birth_date': None, 'address_city': 'ELKTON', 'address_zip': 'MD', 'address_state_code': '21921'}
# {'case_id': '2209451900', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2021, 1, 11, 0, 0), 'filing_date': datetime.datetime(2022, 9, 23, 0, 0), 'arrest_date': None}], 'filing_date': '09/23/2022', 'arrest_date': None, 'offense_date': '01/11/2021', 'first_name': 'SEREEN', 'middle_name': 'ABDULSLAM', 'last_name': 'A ALGHAMDI', 'gender': 'O', 'birth_date': None, 'address_city': 'TOWSON', 'address_zip': 'MD', 'address_state_code': '21286'}
# {'case_id': '2209451700', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2021, 1, 4, 0, 0), 'filing_date': datetime.datetime(2022, 9, 23, 0, 0), 'arrest_date': None}], 'filing_date': '09/23/2022', 'arrest_date': None, 'offense_date': '01/04/2021', 'first_name': 'SEREEN', 'middle_name': 'ABDULSLAM', 'last_name': 'A ALGHAMDI', 'gender': 'O', 'birth_date': None, 'address_city': 'TOWSON', 'address_zip': 'MD', 'address_state_code': '21286'}
# {'case_id': '2209451800', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2021, 1, 4, 0, 0), 'filing_date': datetime.datetime(2022, 9, 23, 0, 0), 'arrest_date': None}], 'filing_date': '09/23/2022', 'arrest_date': None, 'offense_date': '01/04/2021', 'first_name': 'SEREEN', 'middle_name': 'ABDULSLAM', 'last_name': 'A ALGHAMDI', 'gender': 'O', 'birth_date': None, 'address_city': 'TOWSON', 'address_zip': 'MD', 'address_state_code': '21286'}
# {'case_id': '2106588300', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2019, 12, 19, 0, 0), 'filing_date': datetime.datetime(2021, 7, 28, 0, 0), 'arrest_date': None}], 'filing_date': '07/28/2021', 'arrest_date': None, 'offense_date': '12/19/2019', 'first_name': 'ABDULLAH', 'middle_name': 'KALHID', 'last_name': 'A ALMANSOUR', 'gender': 'O', 'birth_date': None, 'address_city': 'BALTIMORE', 'address_zip': 'MD', 'address_state_code': '21201'}
# {'case_id': '2106588400', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2019, 12, 19, 0, 0), 'filing_date': datetime.datetime(2021, 7, 28, 0, 0), 'arrest_date': None}], 'filing_date': '07/28/2021', 'arrest_date': None, 'offense_date': '12/19/2019', 'first_name': 'ABDULLAH', 'middle_name': 'KALHID', 'last_name': 'A ALMANSOUR', 'gender': 'O', 'birth_date': None, 'address_city': 'BALTIMORE', 'address_zip': 'MD', 'address_state_code': '21201'}
# {'case_id': '1902932400', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 3, 20, 0, 0), 'filing_date': datetime.datetime(2019, 2, 7, 0, 0), 'arrest_date': None}], 'filing_date': '02/07/2019', 'arrest_date': None, 'offense_date': '03/20/2018', 'first_name': 'ABDULLAH', 'middle_name': 'KALHID', 'last_name': 'A ALMANSOUR', 'gender': 'O', 'birth_date': None, 'address_city': 'BALTIMORE', 'address_zip': 'MD', 'address_state_code': '21201'}
# {'case_id': '1902931700', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 3, 19, 0, 0), 'filing_date': datetime.datetime(2019, 2, 7, 0, 0), 'arrest_date': None}], 'filing_date': '02/07/2019', 'arrest_date': None, 'offense_date': '03/19/2018', 'first_name': 'ABDULLAH', 'middle_name': 'KALHID', 'last_name': 'A ALMANSOUR', 'gender': 'O', 'birth_date': None, 'address_city': 'BALTIMORE', 'address_zip': 'MD', 'address_state_code': '21201'}
# {'case_id': '1902931800', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 3, 19, 0, 0), 'filing_date': datetime.datetime(2019, 2, 7, 0, 0), 'arrest_date': None}], 'filing_date': '02/07/2019', 'arrest_date': None, 'offense_date': '03/19/2018', 'first_name': 'ABDULLAH', 'middle_name': 'KALHID', 'last_name': 'A ALMANSOUR', 'gender': 'O', 'birth_date': None, 'address_city': 'BALTIMORE', 'address_zip': 'MD', 'address_state_code': '21201'}
# {'case_id': '1901466800', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 2, 16, 0, 0), 'filing_date': datetime.datetime(2019, 1, 23, 0, 0), 'arrest_date': None}], 'filing_date': '01/23/2019', 'arrest_date': None, 'offense_date': '02/16/2018', 'first_name': 'ABULLAH', 'middle_name': 'MOEDH', 'last_name': 'A ALQHTANI', 'gender': 'O', 'birth_date': None, 'address_city': 'PIKESVILLE', 'address_zip': 'MD', 'address_state_code': '21208'}
# {'case_id': '1901459500', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 2, 2, 0, 0), 'filing_date': datetime.datetime(2019, 1, 23, 0, 0), 'arrest_date': None}], 'filing_date': '01/23/2019', 'arrest_date': None, 'offense_date': '02/02/2018', 'first_name': 'ABULLAH', 'middle_name': 'MOEDH', 'last_name': 'A ALQHTANI', 'gender': 'O', 'birth_date': None, 'address_city': 'PIKESVILLE', 'address_zip': 'MD', 'address_state_code': '21208'}
# {'case_id': '1901457100', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 1, 30, 0, 0), 'filing_date': datetime.datetime(2019, 1, 23, 0, 0), 'arrest_date': None}], 'filing_date': '01/23/2019', 'arrest_date': None, 'offense_date': '01/30/2018', 'first_name': 'ABULLAH', 'middle_name': 'MOEDH', 'last_name': 'A ALQHTANI', 'gender': 'O', 'birth_date': None, 'address_city': 'PIKESVILLE', 'address_zip': 'MD', 'address_state_code': '21208'}
# {'case_id': '1901445100', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 1, 11, 0, 0), 'filing_date': datetime.datetime(2019, 1, 23, 0, 0), 'arrest_date': None}], 'filing_date': '01/23/2019', 'arrest_date': None, 'offense_date': '01/11/2018', 'first_name': 'ABULLAH', 'middle_name': 'MOEDH', 'last_name': 'A ALQHTANI', 'gender': 'O', 'birth_date': None, 'address_city': 'PIKESVILLE', 'address_zip': 'MD', 'address_state_code': '21208'}
# {'case_id': '1808369200', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2016, 11, 26, 0, 0), 'filing_date': datetime.datetime(2018, 4, 17, 0, 0), 'arrest_date': None}], 'filing_date': '04/17/2018', 'arrest_date': None, 'offense_date': '11/26/2016', 'first_name': 'ABDULLAH', 'middle_name': 'GHALEB', 'last_name': 'A ALSHARIF', 'gender': 'O', 'birth_date': None, 'address_city': 'COLLEGE PARK', 'address_zip': 'MD', 'address_state_code': '20740'}
# {'case_id': '1808369100', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2016, 11, 25, 0, 0), 'filing_date': datetime.datetime(2018, 4, 17, 0, 0), 'arrest_date': None}], 'filing_date': '04/17/2018', 'arrest_date': None, 'offense_date': '11/25/2016', 'first_name': 'ABDULLAH', 'middle_name': 'GHALEB', 'last_name': 'A ALSHARIF', 'gender': 'O', 'birth_date': None, 'address_city': 'COLLEGE PARK', 'address_zip': 'MD', 'address_state_code': '20740'}
# {'case_id': '1808342900', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2016, 10, 27, 0, 0), 'filing_date': datetime.datetime(2018, 4, 17, 0, 0), 'arrest_date': None}], 'filing_date': '04/17/2018', 'arrest_date': None, 'offense_date': '10/27/2016', 'first_name': 'ABDULLAH', 'middle_name': 'GHALEB', 'last_name': 'A ALSHARIF', 'gender': 'O', 'birth_date': None, 'address_city': 'COLLEGE PARK', 'address_zip': 'MD', 'address_state_code': '20740'}
# {'case_id': '2100805900', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2019, 8, 4, 0, 0), 'filing_date': datetime.datetime(2021, 1, 26, 0, 0), 'arrest_date': None}], 'filing_date': '01/26/2021', 'arrest_date': None, 'offense_date': '08/04/2019', 'first_name': 'ABDULRAHMAN', 'middle_name': 'TAWFIQ', 'last_name': 'A ALSHIHA', 'gender': 'O', 'birth_date': None, 'address_city': 'SILVER SPRING', 'address_zip': 'MD', 'address_state_code': '20901'}
# {'case_id': '2100806000', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2019, 8, 4, 0, 0), 'filing_date': datetime.datetime(2021, 1, 26, 0, 0), 'arrest_date': None}], 'filing_date': '01/26/2021', 'arrest_date': None, 'offense_date': '08/04/2019', 'first_name': 'ABDULRAHMAN', 'middle_name': 'TAWFIQ', 'last_name': 'A ALSHIHA', 'gender': 'O', 'birth_date': None, 'address_city': 'SILVER SPRING', 'address_zip': 'MD', 'address_state_code': '20901'}
# {'case_id': '1924685500', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 12, 26, 0, 0), 'filing_date': datetime.datetime(2019, 12, 6, 0, 0), 'arrest_date': None}], 'filing_date': '12/06/2019', 'arrest_date': None, 'offense_date': '12/26/2018', 'first_name': 'ABDULRAHMAN', 'middle_name': 'TAWFIQ', 'last_name': 'A ALSHIHA', 'gender': 'O', 'birth_date': None, 'address_city': 'SILVER SPRING', 'address_zip': 'MD', 'address_state_code': '20901'}
# {'case_id': '1924680300', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 12, 17, 0, 0), 'filing_date': datetime.datetime(2019, 12, 6, 0, 0), 'arrest_date': None}], 'filing_date': '12/06/2019', 'arrest_date': None, 'offense_date': '12/17/2018', 'first_name': 'ABDULRAHMAN', 'middle_name': 'TAWFIQ', 'last_name': 'A ALSHIHA', 'gender': 'O', 'birth_date': None, 'address_city': 'SILVER SPRING', 'address_zip': 'MD', 'address_state_code': '20901'}
# {'case_id': '1924679400', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 12, 15, 0, 0), 'filing_date': datetime.datetime(2019, 12, 6, 0, 0), 'arrest_date': None}], 'filing_date': '12/06/2019', 'arrest_date': None, 'offense_date': '12/15/2018', 'first_name': 'ABDULRAHMAN', 'middle_name': 'TAWFIQ', 'last_name': 'A ALSHIHA', 'gender': 'O', 'birth_date': None, 'address_city': 'SILVER SPRING', 'address_zip': 'MD', 'address_state_code': '20901'}
# {'case_id': '1924670700', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2018, 11, 22, 0, 0), 'filing_date': datetime.datetime(2019, 12, 6, 0, 0), 'arrest_date': None}], 'filing_date': '12/06/2019', 'arrest_date': None, 'offense_date': '11/22/2018', 'first_name': 'ABDULRAHMAN', 'middle_name': 'TAWFIQ', 'last_name': 'A ALSHIHA', 'gender': 'O', 'birth_date': None, 'address_city': 'SILVER SPRING', 'address_zip': 'MD', 'address_state_code': '20901'}
# {'case_id': '1812280600', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2016, 12, 3, 0, 0), 'filing_date': datetime.datetime(2018, 6, 12, 0, 0), 'arrest_date': None}], 'filing_date': '06/12/2018', 'arrest_date': None, 'offense_date': '12/03/2016', 'first_name': 'MOHAMMED', 'middle_name': 'ABDULLA', 'last_name': 'A ALSHUWAIER', 'gender': 'O', 'birth_date': None, 'address_city': 'TOWSON', 'address_zip': 'MD', 'address_state_code': '21204'}
# {'case_id': '1812274800', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2016, 10, 21, 0, 0), 'filing_date': datetime.datetime(2018, 6, 12, 0, 0), 'arrest_date': None}], 'filing_date': '06/12/2018', 'arrest_date': None, 'offense_date': '10/21/2016', 'first_name': 'MOHAMMED', 'middle_name': 'ABDULLA', 'last_name': 'A ALSHUWAIER', 'gender': 'O', 'birth_date': None, 'address_city': 'TOWSON', 'address_zip': 'MD', 'address_state_code': '21204'}
# {'case_id': '1601544300', 'court_id': '059G', 'charges': [{'offense_date': datetime.datetime(2015, 5, 1, 0, 0), 'filing_date': datetime.datetime(2016, 1, 14, 0, 0), 'arrest_date': None}], 'filing_date': '01/14/2016', 'arrest_date': None, 'offense_date': '05/01/2015', 'first_name': 'ABDULLAH', 'middle_name': 'BAKHEET', 'last_name': 'A ALZAHRANI', 'gender': 'O', 'birth_date': None, 'address_city': 'FROSTBURG', 'address_zip': 'MD', 'address_state_code': '21532'}
